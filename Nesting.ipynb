# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibratbey/Python-asoslari/blob/main/Nesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NESTING
#
# Ba'zida dasturlash jarayonida lug'atning ichida ro'yxatlar yoki boshqa lug'atni, yoki aksincha ro'yxat ichida lug'atni saqlash ham qo'l kelishi mumkin. Bu ingliz tilida **Nesting** deyiladi. Nesting Pythondagi foydali xususiyatlardan biri.

# %% [markdown]
# # AMALIYOT
#
# - Adabiyot (ilm-fan, san'at, internet) olamidagi 4 ta mashxur shaxlar haqidagi ma'lumotlarni lug'at ko'rinishida saqlang. Lug'atlarni bitta ro'yxatga joylang, va har bir shaxs haqidagi ma'lumotni konsolga chiqaring.
#
# - Yuqoridagi lug'atlarga har bir shaxsning mashxur asarlari ro'yxatini ham qo'shing. For tsikli yordamida muallifning ismi va uning asarlarini konsolga chiqaring.
#
# - Oila a'zolaringiz (do'stlaringiz) dan 3 ta sevimli kino-seriali haqida so'rang. Do'stingiz ismi kalit, uning sevimli kinolarini esa ro'yxat ko'rinishida lug'artga saqlang.  Natijani konsolga chiqaring.
#
# - Davlatlar degan lug'at yarating, lug'at ichida bir nechta davlatlar haqida ma'lumotlarni lug'at ko'rinishida saqlang. Har bir davlat haqida ma'lumotni konsolga chiqaring.
#
# - Yuqoridagi dasturga o'zgartirish kiriting: konsolga barcha davlatlarni emas, foydalanuvchi so'ragan davlat haqida ma'lumot bering. Agar davlat sizning lug'atingizda mavjud bo'lmasa, "Bizda bu davlat haqida ma'lumot yo'q" degan xabarni chiqaring.

# %%
AlXorazmiy = {
        "ismi" : "Abu Abdulloh Muhammad ibn Muso al-Xorazmiy",
        "tugilgan_yili": 780,
        "vafot_yili": 850,
        "sohasi": "Matematika, astronomiya, geografiya"
    }
IbnSino = {
        "ismi" : "Abu Ali al-Husayn ibn Abdulloh ibn Sino",
        "tugilgan_yili": 980,
        "vafot_yili": 1037,
        "sohasi": "Tibbiyot, falsafa, fizika"
    }
IsaakNyuton = {
        "ismi" : "Isaak-Nyuton",
        "tugilgan_yili": 1643,
        "vafot_yili": 1727,
        "sohasi": "Fizika, matematika, astronomiya"
    }
AlbertEynshteyn = {
        "ismi" : "Albert-Eynshteyn",
        "tugilgan_yili": 1879,
        "vafot_yili": 1955,
        "sohasi": "Fizika"
    }
NikolaTesla = {
        "ismi" : "Nikola-Tesla",
        "tugilgan_yili": 1856,
        "vafot_yili": 1943,
        "sohasi": "Elektrotexnika, fizika, muhandislik"
    }

olimlar = [AlXorazmiy,IbnSino,IsaakNyuton,AlbertEynshteyn,NikolaTesla]
for olim in olimlar:
  print(f"Mashhur olim {olim['ismi']} {olim['tugilgan_yili']}  yilda tug'ilib {olim['vafot_yili']} yilda vafot etgan. Sohasi {olim['sohasi']} ")
# Out:
# Mashhur olim Abu Abdulloh Muhammad ibn Muso al-Xorazmiy 780  yilda tug'ilib 850 yilda vafot etgan. Sohasi Matematika, astronomiya, geografiya
# Mashhur olim Abu Ali al-Husayn ibn Abdulloh ibn Sino 980  yilda tug'ilib 1037 yilda vafot etgan. Sohasi Tibbiyot, falsafa, fizika
# Mashhur olim Isaak-Nyuton 1643  yilda tug'ilib 1727 yilda vafot etgan. Sohasi Fizika, matematika, astronomiya
# Mashhur olim Albert-Eynshteyn 1879  yilda tug'ilib 1955 yilda vafot etgan. Sohasi Fizika
# Mashhur olim Nikola-Tesla 1856  yilda tug'ilib 1943 yilda vafot etgan. Sohasi Elektrotexnika, fizika, muhandislik

# %%
AlXorazmiy = {
        "ismi" : "Abu Abdulloh Muhammad ibn Muso al-Xorazmiy",
        "tugilgan_yili": 780,
        "vafot_yili": 850,
        "sohasi": "Matematika, astronomiya, geografiya",
        'asarlari' : ["Al-jabr va al-muqabala kitobi","Hind arifmetika haqida","Astronomik jadvallar (Zij al-Sindhind)"]
    }
IbnSino = {
        "ismi" : "Abu Ali al-Husayn ibn Abdulloh ibn Sino",
        "tugilgan_yili": 980,
        "vafot_yili": 1037,
        "sohasi": "Tibbiyot, falsafa, fizika",
        'asarlari' : ["Tib qonunlari","Shifo kitobi","Najot kitobi"]
    }
IsaakNyuton = {
        "ismi" : "Isaak-Nyuton",
        "tugilgan_yili": 1643,
        "vafot_yili": 1727,
        "sohasi": "Fizika, matematika, astronomiya",
        'asarlari' : ["Philosophiae Naturalis Principia Mathematica","Opticks","Method of Fluxions"]
    }
AlbertEynshteyn = {
        "ismi" : "Albert-Eynshteyn",
        "tugilgan_yili": 1879,
        "vafot_yili": 1955,
        "sohasi": "Fizika",
        'asarlari' : ["Relativity: The Special and the General Theory","On the Electrodynamics of Moving Bodies","Investigations on the Theory of Brownian Movement"]
    }
NikolaTesla = {
        "ismi" : "Nikola-Tesla",
        "tugilgan_yili": 1856,
        "vafot_yili": 1943,
        "sohasi": "Elektrotexnika, fizika, muhandislik",
        'asarlari' : ["The Problem of Increasing Human Energy","My Inventions","Experiments with Alternate Currents of High Potential and High Frequency"]
    }

olimlar = [AlXorazmiy,IbnSino,IsaakNyuton,AlbertEynshteyn,NikolaTesla]
for olim in olimlar:
  print(f"\nMashhur olim {olim['ismi']} ning mashhur asarlari: ")
  for asar in olim['asarlari'] :
    print(asar)
# Out:
# Mashhur olim Abu Abdulloh Muhammad ibn Muso al-Xorazmiy ning mashhur asarlari:
# Al-jabr va al-muqabala kitobi
# Hind arifmetika haqida
# Astronomik jadvallar (Zij al-Sindhind)
#
# Mashhur olim Abu Ali al-Husayn ibn Abdulloh ibn Sino ning mashhur asarlari:
# Tib qonunlari
# Shifo kitobi
# Najot kitobi
#
# Mashhur olim Isaak-Nyuton ning mashhur asarlari:
# Philosophiae Naturalis Principia Mathematica
# Opticks
# Method of Fluxions
#
# Mashhur olim Albert-Eynshteyn ning mashhur asarlari:
# Relativity: The Special and the General Theory
# On the Electrodynamics of Moving Bodies
# Investigations on the Theory of Brownian Movement
#
# Mashhur olim Nikola-Tesla ning mashhur asarlari:
# The Problem of Increasing Human Energy
# My Inventions
# Experiments with Alternate Currents of High Potential and High Frequency

# %%
dostlar = ['Ali', 'vali', 'Akmal']
sevimli_kinolar = {}
for dost in dostlar:
  kinolar = []
  n = int(input(f"Hurmatli do'stim {dost} nechta sevimli filming bor ? "))
  for m in range(n):
    kinolar.append(input(f"{m+1} - film : "))
  sevimli_kinolar[dost] = kinolar
print(f"Do'stlarimning sevimli kinolari {sevimli_kinolar}")
# Out:
# Hurmatli do'stim Ali nechta sevimli filming bor ? 2
# 1 - film : fgdhsgfh
# 2 - film : fhsdgf
# Hurmatli do'stim vali nechta sevimli filming bor ? 1
# 1 - film : fdhfdhsdfh
# Hurmatli do'stim Akmal nechta sevimli filming bor ? 3
# 1 - film : ghjwegfh
# 2 - film : jfhghef
# 3 - film : jfgdhjf
# Do'stlarimning sevimli kinolari {'Ali': ['fgdhsgfh', 'fhsdgf'], 'vali': ['fdhfdhsdfh'], 'Akmal': ['ghjwegfh', 'jfhghef', 'jfgdhjf']}

# %%
# Davlatlar lug'ati
davlatlar = {
    "Uzbekistan": {
        "poytaxt": "Toshkent",
        "aholi": 38_000_000,
        "til": "O'zbek tili"
    },
    "Turkey": {
        "poytaxt": "Ankara",
        "aholi": 85_000_000,
        "til": "Turk tili"
    },
    "Japan": {
        "poytaxt": "Tokio",
        "aholi": 125_000_000,
        "til": "Yapon tili"
    }
}

# Har bir davlat haqida ma'lumot chiqarish
for nom, info in davlatlar.items():
    print(f"--- {nom} ---")
    print(f"Poytaxt: {info['poytaxt']}")
    print(f"Aholi soni: {info['aholi']}")
    print(f"Asosiy til: {info['til']}\n")
# Out:
# --- Uzbekistan ---
# Poytaxt: Toshkent
# Aholi soni: 38000000
# Asosiy til: O'zbek tili
#
# --- Turkey ---
# Poytaxt: Ankara
# Aholi soni: 85000000
# Asosiy til: Turk tili
#
# --- Japan ---
# Poytaxt: Tokio
# Aholi soni: 125000000
# Asosiy til: Yapon tili

# %%
davlat =  input("Qaysi davlat haqida qiziqyapsiz ? ").title()
if davlat not in davlatlar :
  print("Bizda bu davlat haqida ma'lumot yo'q")
else :
  print(f" --- {davlat} ---")
  davlat = davlatlar[davlat]
  print(f"Poytaxt: {davlat['poytaxt']}")
  print(f"Aholi soni: {davlat['aholi']}")
  print(f"Asosiy til: {davlat['til']}\n")
# Out:
# Qaysi davlat haqida qiziqyapsiz ? japan
#  --- Japan ---
# Poytaxt: Tokio
# Aholi soni: 125000000
# Asosiy til: Yapon tili
