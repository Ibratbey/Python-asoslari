# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibratbey/Python-asoslari/blob/main/function_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AMALIYOT
# - Matnlardan iborat ro'yxat qabul qilib, ro'yxatdagi har bir matnning birinchi harfini katta harfga o'zgatiruvchi funksiya yozing.
# - Yuqoridagi funksiyani asl ro'yxatni o'zgartirmaydigan va yangi ro'yxat qaytaradigan qilib o'zgartiring
# - Darsimiz davomida yozgan `bahola` funksiyasini `.pop()` metodidan foydalanmasdan va asl ro'yxatga o'zgartirish kiritmasdan faqat lug'at qaytaradigan qilib yozing.

# %% [markdown]
# # JAVOBLAR

# %%
def list_title(matnlar):
  """ Matnlardan iborat ro'yxat qabul qilib, ro'yxatdagi har bir matnning birinchi harfini katta harfga o'zgatiruvchi funksiya """
  matnlar_title = []
  for matn in matnlar :
    matnlar_title.append(matn.title())
  return matnlar_title

ismlar = ['akbar', 'anvar', 'Qamchibek','jamshid']
print(list_title(ismlar))
print(f"Asl ro'yhat : \n{ismlar}")
# Out:
# ['Akbar', 'Anvar', 'Qamchibek', 'Jamshid']
# Asl ro'yhat :
# ['akbar', 'anvar', 'Qamchibek', 'jamshid']

# %%
def bahola(ismlar):
    baholar = {}
    for ism in ismlar:
        baho = input(f"Talaba {ism.title()}ning bahosini kiriting: ")
        baholar[ism]=baho
    return baholar
talabalar = ['qamar', 'vali', 'hasan', 'husan','jamshid']
baholar = bahola(talabalar)
print(baholar)
# Out:
# Talaba Qamarning bahosini kiriting: 5
# Talaba Valining bahosini kiriting: 4
# Talaba Hasanning bahosini kiriting: 5
# Talaba Husanning bahosini kiriting: 5
# Talaba Jamshidning bahosini kiriting: 3
# {'qamar': '5', 'vali': '4', 'hasan': '5', 'husan': '5', 'jamshid': '3'}
