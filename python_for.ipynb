# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibratbey/Python-asoslari/blob/main/python_for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AMALIYOT
# - Kamida 5 elementdan iborat ismlar degan ro'yxat tuzing, va ro'yxatdagi har bir ismga takrorlanuvchi xabar yozing
# - Yuqoridagi tsikl tugaganidan so'ng, ekranga "Kod n marta takrorlandi" degan xabarni chiqaring (n o'rniga kod necha marta takrorlanganini yozing)
# - 10 dan 100 gacha bo'lgan toq sonlar ro'yxatini tuzing. Ro'yxatning xar bir elementining kubini yangi qatordan konsolga chiqaring.
# - Foydalanuvchidan 5 ta eng sevimli kinolarini kiritshni so'rang, va kinolar degan ro'yxatga saqlab oling. Natijani konsolga chiqaring.
# - Foydalanuvchidan bugun nechta odam bilan uchrashganini (suhbatlashganini) so'rang, va har bir suhbatlashgan odamning ismini birma-bir so'rab ro'yxatga yozing. Ro'yxatni konsolga chiqaring.

# %%
#Kamida 5 elementdan iborat ismlar degan ro'yxat tuzing, va ro'yxatdagi har bir ismga takrorlanuvchi xabar yozing
ismlar = ["Abdulloh", "Ali", "Holid", "Anvar", "Sobir"]
for ism in ismlar:
  print(f"Assalomu alaykum {ism}")
# Out:
# Assalomu alaykum Abdulloh
# Assalomu alaykum Ali
# Assalomu alaykum Holid
# Assalomu alaykum Anvar
# Assalomu alaykum Sobir

# %%
#Yuqoridagi tsikl tugaganidan so'ng, ekranga "Kod n marta takrorlandi" degan xabarni chiqaring (n o'rniga kod necha marta takrorlanganini yozing)
print(f"Kod {len(ismlar)} marta takrorlandi!")
# Out:
# Kod 5 marta takrorlandi!

# %%
#10 dan 100 gacha bo'lgan toq sonlar ro'yxatini tuzing. Ro'yxatning xar bir elementining kubini yangi qatordan konsolga chiqaring.
sonlar = list(range(11,100,2))
for son in sonlar:
  print(f"{son} ning kubi : {son**3}")
# Out:
# 11 ning kubi : 1331
# 13 ning kubi : 2197
# 15 ning kubi : 3375
# 17 ning kubi : 4913
# 19 ning kubi : 6859
# 21 ning kubi : 9261
# 23 ning kubi : 12167
# 25 ning kubi : 15625
# 27 ning kubi : 19683
# 29 ning kubi : 24389
# 31 ning kubi : 29791
# 33 ning kubi : 35937
# 35 ning kubi : 42875
# 37 ning kubi : 50653
# 39 ning kubi : 59319
# 41 ning kubi : 68921
# 43 ning kubi : 79507
# 45 ning kubi : 91125
# 47 ning kubi : 103823
# 49 ning kubi : 117649
# 51 ning kubi : 132651
# 53 ning kubi : 148877
# 55 ning kubi : 166375
# 57 ning kubi : 185193
# 59 ning kubi : 205379
# 61 ning kubi : 226981
# 63 ning kubi : 250047
# 65 ning kubi : 274625
# 67 ning kubi : 300763
# 69 ning kubi : 328509
# 71 ning kubi : 357911
# 73 ning kubi : 389017
# 75 ning kubi : 421875
# 77 ning kubi : 456533
# 79 ning kubi : 493039
# 81 ning kubi : 531441
# 83 ning kubi : 571787
# 85 ning kubi : 614125
# 87 ning kubi : 658503
# 89 ning kubi : 704969
# 91 ning kubi : 753571
# 93 ning kubi : 804357
# 95 ning kubi : 857375
# 97 ning kubi : 912673
# 99 ning kubi : 970299

# %%
#Foydalanuvchidan 5 ta eng sevimli kinolarini kiritshni so'rang, va kinolar degan ro'yxatga saqlab oling. Natijani konsolga chiqaring.
kinolar = []
print("Assalomu alaykum, 5 ta sevimli kinolaringiz nomini kiriting!")
for n in range(5):
  kinolar.append(input(f"{n+1} - sevimli kinoyingiz nomini kiriting : "))
print(f"Sizning sevimli filmlaringiz : \n{kinolar}")
# Out:
# Assalomu alaykum, 5 ta sevimli kinolaringiz nomini kiriting!
# 1 - sevimli kinoyingiz nomini kiriting : ona
# 2 - sevimli kinoyingiz nomini kiriting : Vatan
# 3 - sevimli kinoyingiz nomini kiriting : Nomus
# 4 - sevimli kinoyingiz nomini kiriting : Kurulus Osman
# 5 - sevimli kinoyingiz nomini kiriting : Jangchi
# Sizning sevimli filmlaringiz :
# ['ona', 'Vatan', 'Nomus', 'Kurulus Osman', 'Jangchi']

# %%
#Foydalanuvchidan bugun nechta odam bilan uchrashganini (suhbatlashganini) so'rang, va har bir suhbatlashgan odamning ismini birma-bir so'rab ro'yxatga yozing. Ro'yxatni konsolga chiqaring.
n = int(input("Bugun nechta odam bilan ushrashdingiz? : "))
ismlar = []
for i in range(n):
  ismlar.append(input(f"{i+1} - uchrashgan odamingizning ismi : "))
print(ismlar)
# Out:
# Bugun nechta odam bilan ushrashdingiz? : 3
# 1 - uchrashgan odamingizning ismi : Ali
# 2 - uchrashgan odamingizning ismi : VAli
# 3 - uchrashgan odamingizning ismi : Akmal
# ['Ali', 'VAli', 'Akmal']
