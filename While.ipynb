# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibratbey/Python-asoslari/blob/main/While.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  `while` TSIKLI

# %% [markdown]
# # AMALIYOT
#
# 1. Foydalanuvchidan yaxshi ko'rgan kitoblarini kiritishni so'rang. Foydalanuvchi stop so'zini yozishi bilan dasturni to'xtating
# 2. Muzeyga chipta narhi foydalanuvchining yoshiga bog'liq: 7 dan yoshlarga - 2000 so'm, 7-18 gacha 3000 so'm, 18-65 gacha 10000 so'm, 65 dan kattalarga bepul. Shunday while tsikl yozingki, dastur foydalanuvchi yoshini so'rasin va chipta narhini chiqarsin. Foydalanuvchi `exit` yoki `quit` deb yozganda dastur to'xtasin (ikkita shartni ham tekshiring).
#     - Yuqoridagi dasturni turli usullarda yozib ko'ring (break, ishora, yoki shart tekshirish)
# 3. Quyidagi dasturda bir nechta mantiqiy xatolar bor. Jumladan, xusisiy holatlarda tsikl abadiy qaytarilib qolmoqda. Xatolarni to'g'rilay olasizmi?

# %%
savol ="Kiritilgan sonning ildizini qaytaruvchi dastur.\n"
savol += "Musbat son kiriting "
savol += "(dasturni to'xtatish uchun 'exit' deb yozing): "

while True:
    qiymat = input(savol)
    if qiymat<0:
        continue
    elif qiymat=='Exit':
        break
    else:
        ildiz = float(qiymat)**(0.5)
        print(f"{qiymat} ning ildizi {ildiz} ga teng")

# %% [markdown]
# # JAVOBLAR

# %%
kitoblar = []
savol = "Sevimli kitoblaringizni kiriting, hammasini kiritgach 'stop' so'zini kiriting : "
while True:
  javob = input(savol)
  if javob.lower() == 'stop' :
    break
  else :
    kitoblar.append(javob)
print(f"Juda yaxshi! Sizning sevimli kitoblaringiz : \n{kitoblar}")
# Out:
# Sevimli kitoblaringizni kiriting, hammasini kiritgach 'stop' so'zini kiriting : python
# Sevimli kitoblaringizni kiriting, hammasini kiritgach 'stop' so'zini kiriting : Soadat asri qissalari
# Sevimli kitoblaringizni kiriting, hammasini kiritgach 'stop' so'zini kiriting : stop
# Juda yaxshi! Sizning sevimli kitoblaringiz :
# ['python', 'Soadat asri qissalari']

# %%
print("Yoshingizni kiriting, siz uchun chipta narxini aniqlaymiz! Dasturni tugatish uchun exit yoki quit dep yozing")
while True:
  javob = input("Yoshingizni kiriting :")
  if javob.lower() == 'exit' or javob.lower() == 'quit' :
    break
  else :
    yosh = int(javob)
  if yosh < 7 :
    narx = 2000
  elif yosh < 18 :
    narx = 3000
  elif yosh < 65 :
    narx = 10_000
  else :
    narx = 0
  print(f"Sizga chipta narxi {narx} so'm")
# Out:
# Yoshingizni kiriting, siz uchun chipta narxini aniqlaymiz! Dasturni tugatish uchun exit yoki quit dep yozing
# Yoshingizni kiriting :15
# Sizga chipta narxi 3000 so'm
# Yoshingizni kiriting :48
# Sizga chipta narxi 10000 so'm
# Yoshingizni kiriting :5
# Sizga chipta narxi 2000 so'm
# Yoshingizni kiriting :46
# Sizga chipta narxi 10000 so'm
# Yoshingizni kiriting :quit

# %%
print("Kiritilgan sonning ildizini qaytaruvchi dastur.\n")
savol = "Musbat son kiriting "
savol += "(dasturni to'xtatish uchun 'exit' deb yozing): "

while True:
    qiymat = input(savol)
    if qiymat.lower()=='exit':
        break
    else :
      qiymat = float(qiymat)
    if qiymat<0:
        continue
    else:
        ildiz = qiymat**(0.5)
        print(f"{qiymat} ning kvadrat ildizi {ildiz} ga teng")
# Out:
# Kiritilgan sonning ildizini qaytaruvchi dastur.
#
# Musbat son kiriting (dasturni to'xtatish uchun 'exit' deb yozing): 9
# 9.0 ning kvadrat ildizi 3.0 ga teng
# Musbat son kiriting (dasturni to'xtatish uchun 'exit' deb yozing): 16
# 16.0 ning kvadrat ildizi 4.0 ga teng
# Musbat son kiriting (dasturni to'xtatish uchun 'exit' deb yozing): exit
