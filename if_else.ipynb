# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibratbey/Python-asoslari/blob/main/if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10-DARS. `IF-ELSE`
#
# Dasturni tarmoqlashga oid masalalar

# %% [markdown]
# # AMALIYOT
#
# - Yangi `cars = ['toyota', 'mazda', 'hyundai', 'gm', 'kia']` degan ro'yxat tuzing, ro'yxat elementlarining birinchi harfini katta qilib konsolga chqaring. `GM` uchun ikkala harfni katta qiling.
# - Yuqoridagi mashqni teng emas (`!=`) operatori yordamida bajaring.
# - Foydalanuvchi login ismini so'rang. Agar login `admin` bo'lsa, `"Xush kelibsiz, Admin. Foydalanuvchilar ro'yxatini ko'rasizmi?"` xabarini konsolga chiqaring. Aks holda, `"Xush kelibsiz, {foydalanuvchi_ismi}!"`  matnini konsolga chiqaring.
# - Foydalanuvchidan 2 ta son kiritishni so'rang. Agar ikki son bir-biriga teng bo'lsa, `"Sonlar teng"` ekan degan yozuvni konsolga chiqaring.
# - Foydalanuvchidan istalgan son kiritishni so'rang. Agar son manfiy bo'lsa konsolga `"Manfiy son"`, agar musbat bo'lsa `"Musbat son"` degan xabarni chiqaring.
# - Foydalanuvchidan son kiritishni so'rang, agar son musbat bo'lsa uning ildizini hisoblab konsolga chiqaring. Agar son manfiy bo'lsa, `"Musbat son kiriting"` degan xabarni chiqaring.

# %% [markdown]
# # JAVOBLAR

# %%
#Yangi cars = ['toyota', 'mazda', 'hyundai', 'gm', 'kia'] degan ro'yxat tuzing, ro'yxat elementlarining birinchi harfini katta qilib konsolga chqaring. GM uchun ikkala harfni katta qiling.
cars = ['toyota', 'mazda', 'hyundai', 'gm', 'kia']
for car in cars :
  if car.lower() == "gm":
    print(car.upper())
  else :
    print(car.title())
# Out:
# Toyota
# Mazda
# Hyundai
# GM
# Kia

# %%
#Yuqoridagi mashqni teng emas (!=) operatori yordamida bajaring.
for car in cars:
  if car.lower() != "gm":
    print(car.title())
  else :
    print(car.upper())
# Out:
# Toyota
# Mazda
# Hyundai
# GM
# Kia

# %%
#Foydalanuvchi login ismini so'rang. Agar login admin bo'lsa, "Xush kelibsiz, Admin. Foydalanuvchilar ro'yxatini ko'rasizmi?" xabarini konsolga chiqaring. Aks holda, "Xush kelibsiz, {foydalanuvchi_ismi}!" matnini konsolga chiqaring.
login = input("Loginni kiriting : ")
if login.lower() == 'admin':
  print("Xush kelibsiz, Admin. Foydalanuvchilar ro'yxatini ko'rasizmi?")
else:
  print(f"Xush kelibsiz, {login}!")
# Out:
# Loginni kiriting : ibrat
# Xush kelibsiz, ibrat!

# %%
#Foydalanuvchidan 2 ta son kiritishni so'rang. Agar ikki son bir-biriga teng bo'lsa, "Sonlar teng" ekan degan yozuvni konsolga chiqaring.
print("2 ta son kiriting(probel bilan ajratgan holda)")
a, b = map(int, input().split())
if a == b :
  print("Bu sonlar teng ekan!")
# Out:
# 2 ta son kiriting(probel bilan ajratgan holda)
# 5 8

# %%
#Foydalanuvchidan istalgan son kiritishni so'rang. Agar son manfiy bo'lsa konsolga "Manfiy son", agar musbat bo'lsa "Musbat son" degan xabarni chiqaring.
son = int(input("Istalgan son kiriting : "))
if son < 0: print("Manfiy son")
if son >0 : print("Musbat son")
# Out:
# Istalgan son kiriting : 5
# Musbat son

# %%
#Foydalanuvchidan son kiritishni so'rang, agar son musbat bo'lsa uning ildizini hisoblab konsolga chiqaring. Agar son manfiy bo'lsa, "Musbat son kiriting" degan xabarni chiqaring.
x  = int(input("Biror son kiriting >> "))
if x > 0:
  print(f"{x} ning kvadrat ildizi {x ** 0.5} ga teng")
else :
  print("Musbat son kiriting")
# Out:
# Biror son kiriting >> 9
# 9 ning kvadrat ildizi 3.0 ga teng
